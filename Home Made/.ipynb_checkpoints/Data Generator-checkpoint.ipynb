# %%
import pandas as pd
data = pd.read_csv('D:/Internship/dataset/raw.csv')
data.shape
# Out:
# (16, 8)

# %%
data
# Out:
#                Country     Age       Gender  \
# 0                China     0-9         Male
# 1                Italy  Oct-19       Female
# 2                 Iran   20-24  Transgender
# 3   Republic of Korean   25-59          NaN
# 4               France     60+          NaN
# 5                Spain     NaN          NaN
# 6              Germany     NaN          NaN
# 7                  UAE     NaN          NaN
# 8            Other-EUR     NaN          NaN
# 9                Other     NaN          NaN
# 10                 NaN     NaN          NaN
# 11                 NaN     NaN          NaN
# 12                 NaN     NaN          NaN
# 13                 NaN     NaN          NaN
# 14                 NaN     NaN          NaN
# 15                 NaN     NaN          NaN
#
#                                              Symptoms  \
# 0   Fever,Tiredness,Dry-Cough,Difficulty-in-Breath...
# 1   Fever,Tiredness,Dry-Cough,Difficulty-in-Breathing
# 2                           Fever,Tiredness,Dry-Cough
# 3                                     Fever,Tiredness
# 4                                               Fever
# 5   Tiredness,Dry-Cough,Difficulty-in-Breathing,So...
# 6         Tiredness,Dry-Cough,Difficulty-in-Breathing
# 7                                 Tiredness,Dry-Cough
# 8                                           Tiredness
# 9       Dry-Cough,Difficulty-in-Breathing,Sore-Throat
# 10                  Dry-Cough,Difficulty-in-Breathing
# 11                                          Dry-Cough
# 12                Difficulty-in-Breathing,Sore-Throat
# 13                            Difficulty-in-Breathing
# 14                                        Sore-Throat
# 15                                       None_Sympton
#
#                          Experiencing_Symptoms  Severity    Contact  Infected
# 0   Pains,Nasal-Congestion,Runny-Nose,Diarrhea      Mild        Yes       1.0
# 1            Pains,Nasal-Congestion,Runny-Nose  Moderate         No       0.0
# 2                       Pains,Nasal-Congestion    Severe  Dont-Know       NaN
# 3                                        Pains      None        NaN       NaN
# 4         Nasal-Congestion,Runny-Nose,Diarrhea       NaN        NaN       NaN
# 5                  Nasal-Congestion,Runny-Nose       NaN        NaN       NaN
# 6                             Nasal-Congestion       NaN        NaN       NaN
# 7                          Runny-Nose,Diarrhea       NaN        NaN       NaN
# 8                                   Runny-Nose       NaN        NaN       NaN
# 9                                     Diarrhea       NaN        NaN       NaN
# 10                           None_Experiencing       NaN        NaN       NaN
# 11                                         NaN       NaN        NaN       NaN
# 12                                         NaN       NaN        NaN       NaN
# 13                                         NaN       NaN        NaN       NaN
# 14                                         NaN       NaN        NaN       NaN
# 15                                         NaN       NaN        NaN       NaN

# %%
age = len(data.Age.dropna().unique())
gender = len(data.Gender.dropna().unique())
symptoms = len(data.Symptoms.dropna().unique())
esymptoms = len(data.Experiencing_Symptoms.dropna().unique())
severity = len(data.Severity.dropna().unique())
contact = len(data.Contact.dropna().unique())
infected = len(data.Infected.dropna().unique())
print("Total Combination Possible: ",infected * gender * symptoms * esymptoms * severity * contact)
# Out:
# Total Combination Possible:  12672

# %%
import itertools
columns = [data.Country.dropna().unique().tolist(),
          data.Age.dropna().unique().tolist(),
          data.Gender.dropna().unique().tolist(),
          data.Symptoms.dropna().unique().tolist(),
          data.Experiencing_Symptoms.dropna().unique().tolist(),
          data.Severity.dropna().unique().tolist(),
          data.Contact.dropna().unique().tolist(),
          data.Infected.dropna().unique().tolist()]

final_data = pd.DataFrame(list(itertools.product(*columns)), columns=data.columns)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     498     try:
# --> 499         result = _convert_object_array(
#     500             content, columns, dtype=dtype, coerce_float=coerce_float
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     580             # caller's responsibility to check for this...
# --> 581             raise AssertionError(
#     582                 "{col:d} columns passed, passed data had "
#
# AssertionError: 8 columns passed, passed data had 7 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-59b6228b4d41> in <module>
#       8           data.Infected.dropna().unique().tolist()]
#       9
# ---> 10 final_data = pd.DataFrame(list(itertools.product(*columns)), columns=data.columns)
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     448                     if is_named_tuple(data[0]) and columns is None:
#     449                         columns = data[0]._fields
# --> 450                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     451                     columns = ensure_index(columns)
#     452
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     462         return [], []  # columns if columns is not None else []
#     463     if isinstance(data[0], (list, tuple)):
# --> 464         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     465     elif isinstance(data[0], abc.Mapping):
#     466         return _list_of_dict_to_arrays(
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     501         )
#     502     except AssertionError as e:
# --> 503         raise ValueError(e) from e
#     504     return result
#     505
#
# ValueError: 8 columns passed, passed data had 7 columns
