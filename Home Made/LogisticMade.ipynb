# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\Internship\\dataset\\data.csv')

# %%
df.head()
# Out:
#         fever  bodyPain  age  runnyNose  diffBreath  infectionProb
# 0  100.668411         1   68          1           1              1
# 1   99.797366         1   63          0           1              1
# 2   99.854867         1   49          1           0              1
# 3   98.486518         1   24          1          -1              1
# 4  100.723072         1   29          1           1              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2186 entries, 0 to 2185
# Data columns (total 6 columns):
# fever            2186 non-null float64
# bodyPain         2186 non-null int64
# age              2186 non-null int64
# runnyNose        2186 non-null int64
# diffBreath       2186 non-null int64
# infectionProb    2186 non-null int64
# dtypes: float64(1), int64(5)
# memory usage: 102.5 KB

# %%
df['runnyNose'].value_counts()
# Out:
# 1    1103
# 0    1083
# Name: runnyNose, dtype: int64

# %%
df.describe()
# Out:
#              fever     bodyPain          age    runnyNose   diffBreath  \
# count  2186.000000  2186.000000  2186.000000  2186.000000  2186.000000
# mean    100.004803     0.489478    35.380146     0.504575     0.016926
# std       1.151609     0.500004    20.471078     0.500093     0.823114
# min      98.000834     0.000000     1.000000     0.000000    -1.000000
# 25%      99.019113     0.000000    17.000000     0.000000    -1.000000
# 50%      99.989214     0.000000    36.000000     1.000000     0.000000
# 75%     101.005034     1.000000    53.000000     1.000000     1.000000
# max     101.999814     1.000000    70.000000     1.000000     1.000000
#
#        infectionProb
# count    2186.000000
# mean        0.514181
# std         0.499913
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
import numpy as np

# %%
def data_split(data, ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data)*ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train, test = data_split(df, 0.2)

# %%
train[:10]
# Out:
#            fever  bodyPain  age  runnyNose  diffBreath  infectionProb
# 859    99.760241         1   60          1           0              0
# 637   100.251682         1   16          0           1              0
# 478   101.368908         1   34          1          -1              0
# 256    98.472039         0   25          1          -1              1
# 1486   99.252237         0   30          0          -1              0
# 440    99.437466         1   36          0           0              1
# 561   101.977448         1   36          0           0              0
# 2116  101.766672         0   40          0           1              0
# 479    99.283214         0   37          0           1              0
# 1000  101.092695         0   19          1          -1              0
# 596    98.934552         0   60          0          -1              1
# 1258  100.843649         1   22          1          -1              1
# ...

# %%
test[:10]
# Out:
#            fever  bodyPain  age  runnyNose  diffBreath  infectionProb
# 741    99.514573         1   49          1           1              0
# 1315  101.583880         0   33          1          -1              0
# 2051   99.111746         1   59          0           1              0
# 930   100.448537         0   52          0           1              0
# 1476   99.463685         0   42          1           0              1
# 1837   98.274013         0   50          0          -1              0
# 771   101.659145         0   24          0           1              1
# 1735   98.385879         1   38          1           1              1
# 1541  101.530206         0   41          1           1              0
# 567   101.539279         1   19          1          -1              0
# 892    99.068892         0   62          0          -1              0
# 1465  101.846998         1   10          1           0              1
# ...

# %%
X_train = train[['fever','bodyPain','age', 'runnyNose', 'diffBreath']].to_numpy()
X_test = test[['fever','bodyPain','age', 'runnyNose', 'diffBreath']].to_numpy()
X_test
# Out:
# array([[ 99.51457315,   1.        ,  49.        ,   1.        ,
#           1.        ],
#        [101.5838797 ,   0.        ,  33.        ,   1.        ,
#          -1.        ],
#        [ 99.11174626,   1.        ,  59.        ,   0.        ,
#           1.        ],
#        ...,
#        [100.0685961 ,   0.        ,  68.        ,   1.        ,
#           1.        ],
#        [100.0270551 ,   1.        ,  43.        ,   0.        ,
#           0.        ],
#        [101.5093665 ,   1.        ,  68.        ,   0.        ,
#          -1.        ]])

# %%
Y_train = train[['infectionProb']].to_numpy().reshape(1749,)
Y_test = test[['infectionProb']].to_numpy().reshape(437,)

# %%
Y_train
# Out:
# array([0, 0, 0, ..., 0, 1, 1], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()
clf.fit(X_train, Y_train)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = clf.predict(X_test)
print(predictions[:10])
Y_test[:10]
# Out:
# [0 1 0 0 1 1 1 0 1 1]
# array([0, 0, 0, 0, 1, 0, 1, 1, 0, 0], dtype=int64)

# %%
clf.predict([[100,1,22,1,1]])
# Out:
# array([1], dtype=int64)

# %%
inputfeatures = [99.85486676,1,49,1,0]
infProba = clf.predict_proba([inputfeatures])
infProba
# Out:
# array([[0.49523872, 0.50476128]])
